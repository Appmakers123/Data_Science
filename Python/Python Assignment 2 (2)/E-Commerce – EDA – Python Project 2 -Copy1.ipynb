# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

# %%
df = pd.read_csv('Ecommerce.csv', encoding = "ISO-8859-1")
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
#a. Boxplot – All Numeric Variables 
boxplot = df.boxplot(column=['Quantity', 'UnitPrice'], return_type='axes')

# %%
#b. Histogram – All Numeric Variables 
dfh =pd.DataFrame(df, columns=['Quantity', 'UnitPrice'])

ax = dfh.plot.hist(bins=2, alpha=1)

# %%
#c. Distribution Plot – All Numeric Variables 
sns.set()
dfh =pd.DataFrame(df, columns=['Quantity', 'UnitPrice'])

ax = sns.distplot(dfh)

# %%
#d. Aggregation for all numerical Columns 
dfh.agg(['sum', 'min'])
# Out:
#      Quantity    UnitPrice
# sum   5176450  2498803.974
# min    -80995   -11062.060

# %%
#e. Unique Values across all columns

for col in df:
    print(df[col].unique())
# Out:
# ['536365' '536366' '536367' ... '581585' '581586' '581587']
# ['85123A' '71053' '84406B' ... '90214U' '47591b' '23843']
# ['WHITE HANGING HEART T-LIGHT HOLDER' 'WHITE METAL LANTERN'
#  'CREAM CUPID HEARTS COAT HANGER' ... 'lost'
#  'CREAM HANGING HEART T-LIGHT HOLDER' 'PAPER CRAFT , LITTLE BIRDIE']
# [     6      8      2     32      3      4     24     12     48     18
#      20     36     80     64     10    120     96     23      5      1
#      -1     50     40    100    192    432    144    288    -12    -24
#      16      9    128     25     30     28      7     56     72    200
#     600    480     -6     14     -2     11     33     13     -4     -5
#      -7     -3     70    252     60    216    384    -10     27     15
#      22     19     17     21     34     47    108     52  -9360    -38
#      75    270     42    240     90    320   1824    204     69    -36
#    -192   -144    160   2880   1400     39    -48    -50     26   1440
# ...

# %%
#f. Duplicate values across all columns 
df =pd.DataFrame(df)
df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 541904    False
# 541905    False
# 541906    False
# 541907    False
# 541908    False
# Length: 541909, dtype: bool

# %%
#g. Correlation – Heatmap - All Numeric Variables 
Var_Corr = dfh.corr()
# plot the heatmap and annotation on it
sns.heatmap(Var_Corr, xticklabels=Var_Corr.columns, yticklabels=Var_Corr.columns, annot=True)

# %%
#h. Regression Plot - All Numeric Variables

sns.regplot(x="Quantity", y="UnitPrice", data=dfh)

# %%
#i. Bar Plot – Every Categorical Variable vs every Numerical Variable 

dfb = pd.DataFrame(np.random.random(3),['a','b','c']) 
dfb
# Out:
#           0
# a  0.768859
# b  0.170459
# c  0.004344

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
#j. Pair plot - All Numeric Variables
df =pd.DataFrame(df, columns=['Quantity', 'UnitPrice'])
g = sns.pairplot(dfh)

# %%
#k. Line chart to show the trend of data - All Numeric/Date Variables 

import matplotlib.pyplot as plt
dfl =pd.DataFrame(df, columns=['Quantity', 'UnitPrice'])

  
plt.plot(dfl['Quantity'], dfl['UnitPrice'], color='blue', marker='o')
plt.title('Quantity vs Unit Price',fontsize=15)
plt.xlabel('Quantity',fontsize=15)
plt.ylabel('Unit Price',fontsize=15)
plt.grid(True)
plt.show()

# %%
#l. Plot the skewness - All Numeric Variables
#Mean
columns=['Quantity', 'UnitPrice']
fillnamean=df[columns].apply(lambda x: x.fillna(x.mean, inplace=True))
fillnamean
#Mode
fillnamode=df[columns].apply(lambda x: x.fillna(x.mode, inplace=True))
fillnamode
#Median
fillnamedian= df[columns].apply(lambda x: x.fillna(x.median, inplace=True))
fillnamedian
# Out:
# Quantity     None
# UnitPrice    None
# dtype: object

# %%
#Remove duplicate rows 

df.drop_duplicates( keep = False, inplace = True)
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
#Remove rows which have negative values in Quantity column

(df['Quantity'] > 0).all()
# Out:
# False

# %%
#Add the columns - Month, Day and Hour for the invoice 


df2 =pd.DataFrame(df, columns=['InvoiceDate'])
df2['month'] = pd.DatetimeIndex(df['InvoiceDate']).month
df2['day'] = pd.DatetimeIndex(df['InvoiceDate']).day
df2['hour'] = pd.DatetimeIndex(df['InvoiceDate']).hour
df2

# %%
df_result = pd.merge(df, df2, on='InvoiceDate', how='outer')
df_result

# %%
#6. How many orders made by the customers? 
s = df['CustomerID'].value_counts()
s

# %%
#7. TOP 5 customers with higher number of orders 
s1 = df['CustomerID'].groupby(df['Quantity']).count()
s1.head()

# %%
#8. How much money spent by the customers? 
df['Moneyspent'] = df['Quantity'] * df['UnitPrice']
s = df['Moneyspent'].groupby(df['CustomerID']).count()
s

# %%
#9. TOP 5 customers with highest money spent 
s = df['Moneyspent'].head()
s

# %%
#10. How many orders per month? 
df['CustomerID']=df.groupby('month')['Moneyspent'].transform('count')

# %%
#10. How many orders per month?

# %%
#11. How many orders per day?

# %%
#12. How many orders per hour?

# %%
#13. How many orders for each country? 
df['CustomerID']=df.groupby('month')['Moneyspent'].transform('count')

# %%
#14. Orders trend across months

# %%
#15. How much money spent by each country?
